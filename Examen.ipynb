# %%
class promedio:
 def __init__(self, pomedio_calif):
  self.calificacion_1 <= 10

promedio_calif = print(input("Ingresa calificacion1"))
promedio = promedio_calif ()


promedio_calif; print; float(input("Ingrese la calificación2"))
promedio_calif; print; float(input("Ingrese la calificación3"))

suma = (calif1 + calif2 + calif3)
multiplicacion = (suma*10)
promedio = (multiplicacion/3)
print(promedio)



suma = (10 + 8.5 + 29)
multiplicacion = (suma*10)
promedio = (multiplicacion/3)
print(promedio)
