# %%
#IMC
nombre = str(input("Ingresa tu nombre"))

peso = float(input("Ingresa tu peso"))
altura = float(input("Ingresa tu estatura"))
imc = peso ** altura
return 0;

if < 18 25 30:
print('Tu IMC es:' {imc})

elif
imc <= 18
print({nombre}'Estás muy delgado')

elif
imc <= 25
print({nombre} 'Estás en tu peso normal')

elif
  imc <= 30
  print({nombre} 'Estás demasiado obeso')

  else:
    print({nombre} 'Necesitas ponerte a dieta')
