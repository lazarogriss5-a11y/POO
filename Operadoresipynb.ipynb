# %%
print("...Operadores Matemáticos...")
print("...Operación de Suma, 5 + 8 =" , 5 + 8)
print("...Operación de Resta 9 - 7 =" , 9 - 7)
print("...Operación de Multiplicación 5 * 8 =" , 5 * 8)
print("...5 SUMA...")
print("1: 5 + 20 = " , 5 + 20)
print("2: 8 + 30 =" , 8 + 30)
print("3: 25 + 36 =" , 25 + 36)
print("4: 9 + 10 =" , 9 + 10)
print("5: 320 + 3099 =" , 320 + 3099)
print("...5 RESTA...")
print("1: 25 - 15 =" , 25 - 15)
print("2: 99 - 30 =" , 99 - 30)
print("3: 118 - 440 =" , 118 - 440)
print("4: 99 - 50 =" , 99 - 50)
print("5: 110 - 98 =" , 110- 98)
print("...5 MULTIPLICACIÓN...")
print("1: 49 * 115 =" , 40 * 115)
print("2: 9987 * 3076 =" , 9987 * 3076)
print("3: 10 * 44 =" , 10 * 44)
print("4: 991 * 5022 =" , 991 * 5022)
print("5: 110 * 98 =" , 110 * 98)
print("...5 DIVISION...")
print("1: 49 / 115 =" , 40 / 115)
print("2: 9987 / 3076 =" , 9987 / 3076)
print("3: 10 / 44 =" , 10 / 44)
print("4: 991 / 5022 =" , 991 / 5022)
print("5: 110 / 98 =" , 110 / 98)
# Out:
# ...Operadores Matemáticos...
# ...Operación de Suma, 5 + 8 = 13
# ...Operación de Resta 9 - 7 = 2
# ...Operación de Multiplicación 5 * 8 = 40
# ...5 SUMA...
# 1: 5 + 20 =  25
# 2: 8 + 30 = 38
# 3: 25 + 36 = 61
# 4: 9 + 10 = 19
# 5: 320 + 3099 = 3419
# ...5 RESTA...
# 1: 25 - 15 = 10
# 2: 99 - 30 = 69
# 3: 118 - 440 = -322
# 4: 99 - 50 = 49
# 5: 110 - 98 = 12
# ...5 MULTIPLICACIÓN...
# 1: 49 * 115 = 4600
# 2: 9987 * 3076 = 30720012
# 3: 10 * 44 = 440
# 4: 991 * 5022 = 4976802
# 5: 110 * 98 = 10780
# ...5 DIVISION...
# 1: 49 / 115 = 0.34782608695652173
# 2: 9987 / 3076 = 3.2467490247074124
# 3: 10 / 44 = 0.22727272727272727
# 4: 991 / 5022 = 0.19733174034249304
# 5: 110 / 98 = 1.1224489795918366
# 13

# %%
numero1 = 5
numero2 = 8
resultado = numero1 + numero2
print(resultado)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1+n2
print(n1, "+", n2, "=", r)

print("..SUMA..")
n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1+n2
print(n1, "+", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1+n2
print(n1, "+", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1+n2
print(n1, "+", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1+n2
print(n1, "+", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1+n2
print(n1, "+", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1+n2
print(n1, "+", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1+n2
print(n1, "+", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1+n2
print(n1, "+", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1+n2
print(n1, "+", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1+n2
print(n1, "+", n2, "=", r)

print("RESTA")
n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1-n2
print(n1, "-", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1-n2
print(n1, "-", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1-n2
print(n1, "-", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1-n2
print(n1, "-", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1-n2
print(n1, "-", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1-n2
print(n1, "-", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1-n2
print(n1, "-", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1-n2
print(n1, "-", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1-n2
print(n1, "-", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1-n2
print(n1, "-", n2, "=", r)

print("..MULTIPLICACION..")
n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1*n2
print(n1, "*", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1*n2
print(n1, "*", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1*n2
print(n1, "*", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1*n2
print(n1, "*", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1*n2
print(n1, "*", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1*n2
print(n1, "*", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1*n2
print(n1, "*", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1*n2
print(n1, "*", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1*n2
print(n1, "*", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1*n2
print(n1, "*", n2, "=", r)

print("..DIVISION..")
n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1/n2
print(n1, "/", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1/n2
print(n1, "/", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1/n2
print(n1, "/", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1/n2
print(n1, "/", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1/n2
print(n1, "/", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1/n2
print(n1, "/", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero1:"))
r=n1/n2
print(n1, "/", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero2:"))
r=n1/n2
print(n1, "/", n2, "=", r)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero2:"))
r=n1/n2
print(n1, "/", n2, "=", r,)

n1 = int(input("ingrese numero1:"))
n2 = int(input("ingrese numero2:"))
r=n1/n2
print(n1, "/", n2, "=", r,)
# Out:
# 13
# ingrese numero1:1
# ingrese numero1:2
# 1 + 2 = 3
# ..SUMA..
# ingrese numero1:3
# ingrese numero1:2
# 3 + 2 = 5
# ingrese numero1:1
# ingrese numero1:2
# 1 + 2 = 3
# ingrese numero1:1
# ingrese numero1:2
# 1 + 2 = 3
# ingrese numero1:1
# ingrese numero1:2
# 1 + 2 = 3
# ingrese numero1:1
# ingrese numero1:2
# 1 + 2 = 3
# ingrese numero1:1
# ingrese numero1:2
# 1 + 2 = 3
# ingrese numero1:1
# ingrese numero1:2
# 1 + 2 = 3
# ingrese numero1:1
# ingrese numero1:2
# 1 + 2 = 3
# ingrese numero1:1
# ingrese numero1:2
# 1 + 2 = 3
# ingrese numero1:1
# ingrese numero1:2
# 1 + 2 = 3
# RESTA
# ingrese numero1:1
# ingrese numero1:2
# 1 - 2 = -1
# ingrese numero1:1
# ingrese numero1:2
# 1 - 2 = -1
# ingrese numero1:1
# ingrese numero1:2
# 1 - 2 = -1
# ingrese numero1:1
# ingrese numero1:2
# 1 - 2 = -1
# ingrese numero1:1
# ingrese numero1:2
# 1 - 2 = -1
# ingrese numero1:1
# ingrese numero1:2
# 1 - 2 = -1
# ingrese numero1:1
# ingrese numero1:2
# 1 - 2 = -1
# ingrese numero1:1
# ...
